# %%
import Opencv1
from datetime import datetime,date,time

# %%
## the one that works ###

import numpy as np
import cv2
from matplotlib import pyplot as plt


def opencvcam():
    

    faceCascade = cv2.CascadeClassifier('/Users/cv/Documents/haar-cascade-files-master/haarcascade_frontalface_alt.xml')
    

    cap = cv2.VideoCapture(0)

    while(True):
        # Capture frame-by-frame
        ret, frame = cap.read()

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = faceCascade.detectMultiScale(
                gray,
                scaleFactor=1.01,
                minNeighbors=5,
                minSize=(30, 30),
                flags=cv2.CASCADE_SCALE_IMAGE
            )
        
        
        
        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = frame[y:y+h, x:x+w]
            
        cv2.imshow('FaceDetection', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # When everything is done, release the capture
    video_capture.release()
    cv2.destroyAllWindows()
    
opencvcam()

# %%
print(i)

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

faceCascade = cv2.CascadeClassifier('/Users/cv/Documents/haar-cascade-files-master/haarcascade_frontalface_alt.xml')
eyeCascade = cv2.CascadeClassifier('/Users/cv/Documents/haar-cascade-files-master/haarcascade_eye.xml')

cap = cv2.VideoCapture(0)

while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(
            gray,
            scaleFactor=1.5,
            minNeighbors=5,
            minSize=(30, 30),
            flags=cv2.CASCADE_SCALE_IMAGE
        )
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        eyes = eyeCascade.detectMultiScale(roi_gray)
        for (ex,ey,ew,eh) in eyes:
            cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,0,0),2)
            cv2.line(frame, )
        
    cv2.imshow('FaceDetection', frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
# When everything is done, release the capture
video_capture.release()
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from tkinter import Label, Button

def opencvcam(self):
    

    faceCascade = cv2.CascadeClassifier('/Users/cv/Documents/haar-cascade-files-master/haarcascade_frontalface_alt.xml')
    

    cap = cv2.VideoCapture(0)

    while(True):
        # Capture frame-by-frame
        ret, frame = cap.read()

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = faceCascade.detectMultiScale(
                gray,
                scaleFactor=1.5,
                minNeighbors=5,
                minSize=(30, 30),
                flags=cv2.CASCADE_SCALE_IMAGE
            )
        
        facedetect= Label(self,text="Found {0} faces!".format(len(faces))).pack()
        quitfd = Button(self, text = "X").pack()
        
        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = frame[y:y+h, x:x+w]
            

        
        if quitfd.get():
            facedetect.pack_forget
            quitfd.pack_forget
            break

    # When everything is done, release the capture
    video_capture.release()
    cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from tkinter import *
import time

window = Tk()
window.title
window.geometry("1388x856")
Swidth = 1388
Sheight = 856


def opencvcam(self):
    z = 0
    faceCascade = cv2.CascadeClassifier('/Users/cv/Documents/haar-cascade-files-master/haarcascade_frontalface_alt.xml')
    cap = cv2.VideoCapture(0)
    
    
        # Capture frame-by-frame
    ret, frame = cap.read()
    

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    while z <=5:
        faces = faceCascade.detectMultiScale(
                gray,
                scaleFactor=1.5,
                minNeighbors=5,
                minSize=(30, 30),
                flags=cv2.CASCADE_SCALE_IMAGE
            )
        z +=1
            
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        print(faces)
        print('running')
        
    noofppl = str(len(faces)*2)
    fdwaiting = Label(self, text ='Estimated waiting \n time: '+ noofppl + ' mins     ',
                  font=("royal acidbath", 20))
        

    fdwaiting.pack()
        


    # When everything is done, release the capture
    
    cv2.destroyAllWindows()

w = Button(window, text= "Generate real time", command = lambda: opencvcam(window)).pack()

window.mainloop()

# %%
## one that works?
import numpy as np
import cv2
from matplotlib import pyplot as plt
from tkinter import *
import time

window = Tk()
window.title
window.geometry("1388x856")



def opencvcam(self):
    z = 0

    faceCascade = cv2.CascadeClassifier('/Users/cv/Documents/haar-cascade-files-master/haarcascade_frontalface_alt.xml')
    

    cap = cv2.VideoCapture(0)

    while z <=5:
        # Capture frame-by-frame
        ret, frame = cap.read()

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = faceCascade.detectMultiScale(
                gray,
                scaleFactor=1.01,
                minNeighbors=5,
                minSize=(30, 30),
                flags=cv2.CASCADE_SCALE_IMAGE
            )
        z += 1
        
        
        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = frame[y:y+h, x:x+w]
            
        

    noofppl = str(len(faces)*2)
    fdwaiting = Label(self, text ='Estimated waiting \n time: '+ noofppl + ' mins     ',
                  font=("royal acidbath", 20))
        

    fdwaiting.place(x = 1290, y = 150)
    # When everything is done, release the capture
    
    cv2.destroyAllWindows()
    
w = Button(window, text= "Generate real time", command = lambda: opencvcam(window)).pack()

window.mainloop()
